# %% [markdown]
# <a href="https://colab.research.google.com/github/AshaRaniKulhade/Assignments/blob/main/Pandas_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# read Travel_data excel file and create dataframe of number_of_arrival sheet
df = pd.read_excel("/content/drive/MyDrive/AI_ML/travel_data.xls",sheet_name="number_of_arrival",header=3,index_col=False,keep_default_na=True)
df.head()
# Out:
#                 Country Name Country Code  \
# 0                      World          WLD
# 1                High income          HIC
# 2               OECD members          OED
# 3  Post-demographic dividend          PST
# 4      Europe & Central Asia          ECS
#
#                               Indicator Name Indicator Code  1960  1961  1962  \
# 0  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 1  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 2  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 3  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 4  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
#
#    1963  1964  1965  ...          2009          2010          2011  \
# 0   NaN   NaN   NaN  ...  8.975338e+08  9.563723e+08  9.975553e+08
# 1   NaN   NaN   NaN  ...  5.483952e+08  5.794189e+08  6.058485e+08
# ...

# %%
# read Travel_data excel file and store sheet data in different DataFrame
listofsheets = ['number_of_arrival','number_of_departure','expenditure for travel item','receipts for travel items','population','GDP']
# read all sheets from list into an different data frames
df_no_of_arrival,df_no_of_depature,df_expend_for_travel_item,df_receipts_for_travel,df_population,df_gdp = pd.read_excel("/content/drive/MyDrive/AI_ML/travel_data.xls", sheet_name= listofsheets,header=3).values()

#To show all columns of dataset.
pd.set_option('display.max_columns', None)

# show Top 5 records
df_no_of_arrival.head()
# Out:
#                 Country Name Country Code  \
# 0                      World          WLD
# 1                High income          HIC
# 2               OECD members          OED
# 3  Post-demographic dividend          PST
# 4      Europe & Central Asia          ECS
#
#                               Indicator Name Indicator Code  1960  1961  1962  \
# 0  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 1  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 2  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 3  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 4  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
#
#    1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  1973  1974  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
# finding Number of missing values in each columns
df_no_of_arrival.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              264
#                  ...
# 2014               29
# 2015               28
# 2016               34
# 2017               49
# 2018              264
# Length: 63, dtype: int64

# %%
print("Number of Rows in this dataset:-",df_no_of_arrival.shape[0])
print("Number of Columns in this dataset:-",df_no_of_arrival.shape[1])
# Out:
# Number of Rows in this dataset:- 264
# Number of Columns in this dataset:- 63

# %%
df_no_of_arrival.bfill(axis=1)
# Out:
#                   Country Name Country Code  \
# 0                        World          WLD
# 1                  High income          HIC
# 2                 OECD members          OED
# 3    Post-demographic dividend          PST
# 4        Europe & Central Asia          ECS
# ..                         ...          ...
# 259       Syrian Arab Republic          SYR
# 260               Turkmenistan          TKM
# 261      Virgin Islands (U.S.)          VIR
# 262                     Kosovo          XKX
# 263                Yemen, Rep.          YEM
#
#                                 Indicator Name Indicator Code  \
# 0    International tourism, number of arrivals    ST.INT.ARVL
# 1    International tourism, number of arrivals    ST.INT.ARVL
# 2    International tourism, number of arrivals    ST.INT.ARVL
# 3    International tourism, number of arrivals    ST.INT.ARVL
# 4    International tourism, number of arrivals    ST.INT.ARVL
# ...
